# %% [markdown]
# # Polar Codes Vs Machine Learning

# %% [markdown]
# This project has for main goal to propose to whom is interested, a quick display of some of my competences in pyhton, télécommunication and machine learnings.
